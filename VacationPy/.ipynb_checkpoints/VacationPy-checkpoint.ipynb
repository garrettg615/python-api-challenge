# %%
## dependecies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import json
import gmaps
import os
from pprint import pprint

# Import API Key
from vaca_config import go_key

# %%
## import csv file from Output folder and display
city_weather_df = pd.read_csv('../Output/weather_data.csv')
city_weather_df.head()
# Out:
#         City      Lat      Long  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0   kharovsk  59.9642   40.1912     16.75      91.0       100.0       14.27
# 1     atuona  -9.8000 -139.0333     79.83      58.0        20.0        2.17
# 2    shakawe -18.3667   21.8500     65.03      77.0         0.0        5.14
# 3  carnarvon -24.8667  113.6333     91.40      35.0         3.0       14.97
# 4     camana -16.6228  -72.7111     72.95      85.0         1.0        6.96
#
#   Country          Date
# 0      RU  1.615607e+09
# 1      PF  1.615607e+09
# 2      BW  1.615607e+09
# 3      AU  1.615607e+09
# 4      PE  1.615607e+09

# %%
## initialize and configure gmaps with api key
gmaps.configure(api_key=go_key)

# %%
## set variables for Heat map
locations = city_weather_df[['Lat','Long']].astype(float)
city_humidity = city_weather_df['Humidity']

## initialize google map figure for heat map
fig = gmaps.figure()

## define heat map layer using humidity
heat_humidity = gmaps.heatmap_layer(locations, weights=city_humidity,
                                    max_intensity=20)

## Add heat may layer
fig.add_layer(heat_humidity)

## Show figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
## Define the parameters for the ideal vacation spots
ideal_locations_df = city_weather_df.loc[(city_weather_df['Max Temp']>=70)&
                                         (city_weather_df['Max Temp']<=80)&
                                         (city_weather_df['Wind Speed']<=10)&
                                         (city_weather_df['Cloudiness']==0)]

## add a blank column for hotel names for ideal location spots
ideal_locations_df['Hotel'] = ''
# Out:
# <ipython-input-37-250e9f8489c8>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ideal_locations_df['Hotel'] = ''

# %%
## define base url for google places api
base_url = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?locations='

## define the paramaters for the google places api request
params = {'location':'',
         'radius':5000,
         'type':'hotel',
         'key':go_key}

## for loop through city name to get nearest hotel and name to display in dataframe
for index, row in ideal_locations_df.iterrows():
    params['location'] = str(row['Lat']) + ',' + str(row['Long'])
    response = requests.get(base_url, params=params).json()
    
    ideal_locations_df.loc[index, 'Hotel'] = response['results'][1]['name']
# Out:
# /Users/garrettgomez/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1765: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value)

# %%
## display data frame for ideal vacation spots with first hotel name
ideal_locations_df
# Out:
#                 City      Lat      Long  Max Temp  Humidity  Cloudiness  \
# 9           cidreira -30.1811  -50.2056     70.48      79.0         0.0
# 23           cayenne   4.9333  -52.3333     73.40      94.0         0.0
# 30         caravelas -17.7125  -39.2481     72.36      82.0         0.0
# 32       east london -33.0153   27.9116     71.60      88.0         0.0
# 102           bentiu   9.2333   29.8333     77.92      21.0         0.0
# 108  dzilam gonzalez  21.2833  -88.9333     72.28      68.0         0.0
# 199            nioro  13.3500  -15.7500     71.60      14.0         0.0
# 205       vila velha -20.3297  -40.2925     78.80      61.0         0.0
# 227            wuwei  37.9281  102.6414     70.74       5.0         0.0
# 235           wanaka -44.7000  169.1500     73.99      43.0         0.0
# 239          huarmey -10.0681  -78.1522     72.36      81.0         0.0
# 263       coahuayana  18.7333 -103.6833     70.39      70.0         0.0
# 383            paita  -5.0892  -81.1144     78.80      73.0         0.0
# 423         oussouye  12.4850  -16.5469     73.40      73.0         0.0
# 426         belmonte -15.8631  -38.8828     71.60      78.0         0.0
# 495          hualmay -11.0964  -77.6139     71.29      86.0         0.0
# 512         asuncion -25.3007  -57.6359     73.40      68.0         0.0
# 591       uruguaiana -29.7547  -57.0883     71.60      78.0         0.0
#
#      Wind Speed Country          Date  \
# 9          6.04      BR  1.615607e+09
# 23         1.14      GF  1.615607e+09
# 30         4.88      BR  1.615607e+09
# 32         9.22      ZA  1.615607e+09
# 102        2.37      SS  1.615607e+09
# 108        8.63      MX  1.615607e+09
# 199        6.82      GM  1.615607e+09
# 205        5.75      BR  1.615607e+09
# 227        2.75      CN  1.615607e+09
# 235        1.99      NZ  1.615607e+09
# 239        6.49      PE  1.615607e+09
# 263        3.22      MX  1.615607e+09
# 383        8.05      PE  1.615607e+09
# 423        2.30      SN  1.615607e+09
# 426        2.30      BR  1.615607e+09
# 495        6.67      PE  1.615607e+09
# 512        4.61      PY  1.615607e+09
# 591        4.61      BR  1.615607e+09
#
#                                             Hotel
# 9                                   Diego Imóveis
# 23                                Hôtel Le Dronmi
# 30                               Conselho Tutelar
# 32                                        Tu Casa
# 102                              John pawiel Thak
# 108         Presidencia Municipal Dzilam González
# 199                                 Madina Mosque
# 205                     Quality Suites Vila Velha
# 227                                  Haizang Park
# 235           Wanaka Homestead Lodge and Cottages
# 239                                 Hotel Miramar
# 263                               Chonita Bananas
# 383                        Hotel Náutico de Paita
# 423  Asamblea de Cooperacion por la Paz (Senegal)
# 426                           Belmonte Lighthouse
# 495                      Alas Peruanas University
# 512                         Crowne Plaza Asuncion
# 591                             Fares Turis Hotel

# %%
# NOTE: Do not change any of the code in this cell

# Using the template add the hotel marks to the heatmap
info_box_template = """
<dl>
<dt>Hotel Name</dt><dd>{Hotel}</dd>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
</dl>
"""
# Store the DataFrame Row
# NOTE: be sure to update with your DataFrame name
hotel_info = [info_box_template.format(**row) for index, row in ideal_locations_df.iterrows()]
locations = ideal_locations_df[["Lat", "Long"]]

# %%
## create markers with hotel name, city and country
markers = gmaps.marker_layer(locations,info_box_content=hotel_info)
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
