# %%
## import dependencies
import json
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st
from citipy import citipy
from keys import api_key
from pprint import pprint

# %%
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 598

# %%
## Create blank Data Frame with city names
city_weather_df = pd.DataFrame({'City':cities})
city_weather_df['Lat'] = ''
city_weather_df['Long'] = ''
city_weather_df['Max Temp'] = ''
city_weather_df['Humidity'] = ''
city_weather_df['Cloudiness'] = ''
city_weather_df['Wind Speed'] = ''
city_weather_df['Country'] = ''
city_weather_df['Date'] = ''

# %%
## list to store cities not found
not_cities = []

## define the base url for api request
city_url = 'http://api.openweathermap.org/data/2.5/weather?q='

## for loop to iterate through city names to gather weather data
for index, row in city_weather_df.iterrows():
    city_name = row['City']
    response = requests.get(f'{city_url}{city_name}&appid={api_key}&units=imperial').json()
    
    ## Get weather data from json file and store in Data Frame created above
    try:
        print(f'processing record {index} of {len(cities)} | {city_name}')
        city_weather_df.loc[index, 'Lat'] = response['coord']['lat']
        city_weather_df.loc[index, 'Long'] = response['coord']['lon']
        city_weather_df.loc[index, 'Max Temp'] = response['main']['temp_max']
        city_weather_df.loc[index, 'Humidity'] = response['main']['humidity']
        city_weather_df.loc[index, 'Cloudiness'] = response['clouds']['all']
        city_weather_df.loc[index, 'Wind Speed'] = response['wind']['speed']
        city_weather_df.loc[index, 'Country'] = response['sys']['country']
        city_weather_df.loc[index, 'Date'] = response['dt']
        
    
    ## If there is no weather data for the city, print message and add to list of not_cities
    except KeyError:
        print(f'{city_name} not found...skipping')
        not_cities.append(city_name)
# Out:
# processing record 0 of 598 | dingle
# processing record 1 of 598 | busselton
# processing record 2 of 598 | guerrero negro
# processing record 3 of 598 | bluff
# processing record 4 of 598 | bredasdorp
# processing record 5 of 598 | lolua
# lolua not found...skipping
# processing record 6 of 598 | keuruu
# processing record 7 of 598 | kangaba
# processing record 8 of 598 | ostrovnoy
# processing record 9 of 598 | carnarvon
# processing record 10 of 598 | asfi
# processing record 11 of 598 | cabo san lucas
# processing record 12 of 598 | punta arenas
# processing record 13 of 598 | shubarkuduk
# processing record 14 of 598 | kodiak
# processing record 15 of 598 | belushya guba
# belushya guba not found...skipping
# processing record 16 of 598 | barentsburg
# barentsburg not found...skipping
# processing record 17 of 598 | miri
# processing record 18 of 598 | vaini
# processing record 19 of 598 | tautira
# processing record 20 of 598 | port elizabeth
# processing record 21 of 598 | ushuaia
# processing record 22 of 598 | hobart
# processing record 23 of 598 | qaanaaq
# processing record 24 of 598 | talnakh
# processing record 25 of 598 | avallon
# processing record 26 of 598 | loukhi
# processing record 27 of 598 | ayolas
# processing record 28 of 598 | pacific grove
# processing record 29 of 598 | klaksvik
# processing record 30 of 598 | hilo
# processing record 31 of 598 | new norfolk
# processing record 32 of 598 | toora-khem
# processing record 33 of 598 | airai
# processing record 34 of 598 | dikson
# processing record 35 of 598 | nizhneyansk
# nizhneyansk not found...skipping
# processing record 36 of 598 | khasan
# processing record 37 of 598 | puerto penasco
# processing record 38 of 598 | avarua
# processing record 39 of 598 | wenling
# processing record 40 of 598 | mahebourg
# processing record 41 of 598 | rikitea
# processing record 42 of 598 | gravdal
# processing record 43 of 598 | upernavik
# processing record 44 of 598 | nantucket
# processing record 45 of 598 | sentyabrskiy
# sentyabrskiy not found...skipping
# processing record 46 of 598 | asau
# processing record 47 of 598 | tahoua
# processing record 48 of 598 | tiksi
# processing record 49 of 598 | safranbolu
# processing record 50 of 598 | nishihara
# processing record 51 of 598 | sinolon
# processing record 52 of 598 | kapaa
# processing record 53 of 598 | kruisfontein
# processing record 54 of 598 | kerugoya
# processing record 55 of 598 | jaranwala
# processing record 56 of 598 | fort nelson
# processing record 57 of 598 | victoria
# processing record 58 of 598 | coruripe
# processing record 59 of 598 | macheng
# processing record 60 of 598 | atuona
# processing record 61 of 598 | chivacoa
# processing record 62 of 598 | hithadhoo
# processing record 63 of 598 | tsihombe
# tsihombe not found...skipping
# processing record 64 of 598 | yellowknife
# processing record 65 of 598 | kenora
# processing record 66 of 598 | faanui
# processing record 67 of 598 | albany
# processing record 68 of 598 | jiazi
# processing record 69 of 598 | mys shmidta
# mys shmidta not found...skipping
# processing record 70 of 598 | myanaung
# processing record 71 of 598 | hermanus
# processing record 72 of 598 | arraial do cabo
# processing record 73 of 598 | hasaki
# processing record 74 of 598 | bathsheba
# processing record 75 of 598 | leningradskiy
# processing record 76 of 598 | itupiranga
# processing record 77 of 598 | elizabeth city
# processing record 78 of 598 | nioro
# processing record 79 of 598 | butzow
# processing record 80 of 598 | khandyga
# processing record 81 of 598 | saldanha
# processing record 82 of 598 | miyako
# processing record 83 of 598 | nikolskoye
# processing record 84 of 598 | karratha
# processing record 85 of 598 | cape town
# processing record 86 of 598 | vangaindrano
# processing record 87 of 598 | filingue
# processing record 88 of 598 | georgetown
# processing record 89 of 598 | clyde river
# processing record 90 of 598 | havelock
# processing record 91 of 598 | xining
# processing record 92 of 598 | pisco
# processing record 93 of 598 | tuktoyaktuk
# processing record 94 of 598 | havre-saint-pierre
# processing record 95 of 598 | severo-kurilsk
# processing record 96 of 598 | mataura
# processing record 97 of 598 | castro
# processing record 98 of 598 | kavieng
# processing record 99 of 598 | ordu
# processing record 100 of 598 | taolanaro
# taolanaro not found...skipping
# processing record 101 of 598 | antofagasta
# processing record 102 of 598 | grand river south east
# grand river south east not found...skipping
# processing record 103 of 598 | aksum
# processing record 104 of 598 | prince rupert
# processing record 105 of 598 | kaeo
# processing record 106 of 598 | east london
# processing record 107 of 598 | tonj
# processing record 108 of 598 | samusu
# samusu not found...skipping
# processing record 109 of 598 | saint-philippe
# processing record 110 of 598 | puerto carreno
# processing record 111 of 598 | poum
# processing record 112 of 598 | matay
# processing record 113 of 598 | coahuayana
# processing record 114 of 598 | klyuchi
# processing record 115 of 598 | saint-francois
# processing record 116 of 598 | ponta do sol
# processing record 117 of 598 | klaipeda
# processing record 118 of 598 | barrow
# processing record 119 of 598 | itigi
# processing record 120 of 598 | kaspican
# kaspican not found...skipping
# processing record 121 of 598 | mawlaik
# processing record 122 of 598 | jamestown
# processing record 123 of 598 | longyearbyen
# processing record 124 of 598 | warqla
# warqla not found...skipping
# processing record 125 of 598 | severnyy
# processing record 126 of 598 | saint-augustin
# processing record 127 of 598 | tsentralnyy
# tsentralnyy not found...skipping
# processing record 128 of 598 | provideniya
# processing record 129 of 598 | thompson
# processing record 130 of 598 | los llanos de aridane
# processing record 131 of 598 | omboue
# processing record 132 of 598 | pedras de fogo
# processing record 133 of 598 | yumen
# processing record 134 of 598 | sisimiut
# processing record 135 of 598 | zyryanka
# processing record 136 of 598 | illoqqortoormiut
# illoqqortoormiut not found...skipping
# processing record 137 of 598 | lompoc
# processing record 138 of 598 | ugoofaaru
# processing record 139 of 598 | tres arroyos
# processing record 140 of 598 | luderitz
# processing record 141 of 598 | santo nino
# processing record 142 of 598 | sibolga
# processing record 143 of 598 | mehamn
# processing record 144 of 598 | port alfred
# processing record 145 of 598 | gazli
# processing record 146 of 598 | matagami
# processing record 147 of 598 | jaffna
# processing record 148 of 598 | geelong
# processing record 149 of 598 | parainen
# processing record 150 of 598 | butaritari
# processing record 151 of 598 | nouakchott
# processing record 152 of 598 | itarema
# processing record 153 of 598 | rocha
# processing record 154 of 598 | norman wells
# processing record 155 of 598 | zaigrayevo
# processing record 156 of 598 | acajutla
# processing record 157 of 598 | sidney
# processing record 158 of 598 | labuhan
# processing record 159 of 598 | warrington
# processing record 160 of 598 | cayenne
# processing record 161 of 598 | kinross
# processing record 162 of 598 | marawi
# processing record 163 of 598 | salalah
# processing record 164 of 598 | buariki
# buariki not found...skipping
# processing record 165 of 598 | teahupoo
# processing record 166 of 598 | puerto ayora
# processing record 167 of 598 | weinan
# processing record 168 of 598 | skjervoy
# processing record 169 of 598 | nhulunbuy
# processing record 170 of 598 | plouzane
# processing record 171 of 598 | vardo
# processing record 172 of 598 | nome
# processing record 173 of 598 | fournoi
# fournoi not found...skipping
# processing record 174 of 598 | yulara
# processing record 175 of 598 | shache
# processing record 176 of 598 | sur
# processing record 177 of 598 | chapais
# processing record 178 of 598 | paamiut
# processing record 179 of 598 | kloulklubed
# processing record 180 of 598 | ahipara
# processing record 181 of 598 | baykit
# processing record 182 of 598 | marcona
# marcona not found...skipping
# processing record 183 of 598 | mar del plata
# processing record 184 of 598 | andenes
# processing record 185 of 598 | rivne
# processing record 186 of 598 | igarka
# processing record 187 of 598 | port lincoln
# processing record 188 of 598 | cherskiy
# processing record 189 of 598 | west wendover
# processing record 190 of 598 | revadanda
# processing record 191 of 598 | armacao dos buzios
# armacao dos buzios not found...skipping
# processing record 192 of 598 | richards bay
# processing record 193 of 598 | taoudenni
# processing record 194 of 598 | manokwari
# processing record 195 of 598 | narsaq
# processing record 196 of 598 | basoda
# processing record 197 of 598 | nanortalik
# processing record 198 of 598 | sonoita
# processing record 199 of 598 | nikolsk
# processing record 200 of 598 | macae
# processing record 201 of 598 | gat
# processing record 202 of 598 | camacha
# processing record 203 of 598 | bethel
# processing record 204 of 598 | torata
# processing record 205 of 598 | vilcun
# processing record 206 of 598 | storm lake
# processing record 207 of 598 | aquiraz
# processing record 208 of 598 | tasiilaq
# processing record 209 of 598 | felidhoo
# felidhoo not found...skipping
# processing record 210 of 598 | phuket
# processing record 211 of 598 | mashhad
# processing record 212 of 598 | teguldet
# processing record 213 of 598 | douentza
# processing record 214 of 598 | attawapiskat
# attawapiskat not found...skipping
# processing record 215 of 598 | kutulik
# processing record 216 of 598 | souillac
# processing record 217 of 598 | tabuny
# processing record 218 of 598 | barmer
# processing record 219 of 598 | bargal
# bargal not found...skipping
# processing record 220 of 598 | mlalo
# processing record 221 of 598 | pochutla
# processing record 222 of 598 | palmer
# processing record 223 of 598 | coquimbo
# processing record 224 of 598 | tilichiki
# processing record 225 of 598 | chuy
# processing record 226 of 598 | fairmont
# processing record 227 of 598 | vaitupu
# vaitupu not found...skipping
# processing record 228 of 598 | adrar
# processing record 229 of 598 | along
# processing record 230 of 598 | kawalu
# processing record 231 of 598 | gilgit
# processing record 232 of 598 | jalu
# processing record 233 of 598 | ravar
# processing record 234 of 598 | novikovo
# processing record 235 of 598 | san quintin
# processing record 236 of 598 | bodden town
# processing record 237 of 598 | devarkonda
# processing record 238 of 598 | sakakah
# processing record 239 of 598 | sitka
# processing record 240 of 598 | constitucion
# processing record 241 of 598 | launceston
# processing record 242 of 598 | canutama
# processing record 243 of 598 | cabedelo
# processing record 244 of 598 | karakendzha
# karakendzha not found...skipping
# processing record 245 of 598 | dwarka
# processing record 246 of 598 | pevek
# processing record 247 of 598 | tiznit
# processing record 248 of 598 | telde
# processing record 249 of 598 | sidi qasim
# sidi qasim not found...skipping
# processing record 250 of 598 | grand-santi
# processing record 251 of 598 | santa isabel do rio negro
# processing record 252 of 598 | portland
# processing record 253 of 598 | petropavlovsk-kamchatskiy
# processing record 254 of 598 | bambous virieux
# processing record 255 of 598 | kahului
# processing record 256 of 598 | katsuura
# processing record 257 of 598 | olinda
# processing record 258 of 598 | pedasi
# processing record 259 of 598 | torbay
# processing record 260 of 598 | namibe
# processing record 261 of 598 | isangel
# processing record 262 of 598 | quatre cocos
# processing record 263 of 598 | kuche
# kuche not found...skipping
# processing record 264 of 598 | caravelas
# processing record 265 of 598 | markova
# processing record 266 of 598 | chokurdakh
# processing record 267 of 598 | owando
# processing record 268 of 598 | erdenet
# processing record 269 of 598 | vanimo
# processing record 270 of 598 | tigzirt
# processing record 271 of 598 | soc trang
# processing record 272 of 598 | potlogi
# processing record 273 of 598 | salinopolis
# processing record 274 of 598 | geraldton
# processing record 275 of 598 | srednekolymsk
# processing record 276 of 598 | kaniama
# processing record 277 of 598 | ko samui
# processing record 278 of 598 | poronaysk
# processing record 279 of 598 | xushan
# processing record 280 of 598 | coromandel
# processing record 281 of 598 | hamilton
# processing record 282 of 598 | samarinda
# processing record 283 of 598 | pasighat
# processing record 284 of 598 | doha
# processing record 285 of 598 | yar-sale
# processing record 286 of 598 | alekseyevsk
# processing record 287 of 598 | labuan
# processing record 288 of 598 | tuatapere
# processing record 289 of 598 | bratsk
# processing record 290 of 598 | mujiayingzi
# processing record 291 of 598 | maniitsoq
# processing record 292 of 598 | killybegs
# processing record 293 of 598 | aflu
# aflu not found...skipping
# processing record 294 of 598 | kedgwick
# processing record 295 of 598 | beyneu
# processing record 296 of 598 | fenoarivo
# processing record 297 of 598 | wanning
# processing record 298 of 598 | fare
# processing record 299 of 598 | sabinas
# processing record 300 of 598 | cairns
# processing record 301 of 598 | galesong
# processing record 302 of 598 | rancho santa margarita
# processing record 303 of 598 | vila
# processing record 304 of 598 | methoni
# processing record 305 of 598 | oussouye
# processing record 306 of 598 | alofi
# processing record 307 of 598 | domoni
# processing record 308 of 598 | lebu
# processing record 309 of 598 | rungata
# rungata not found...skipping
# processing record 310 of 598 | amderma
# amderma not found...skipping
# processing record 311 of 598 | prevalje
# processing record 312 of 598 | nyurba
# processing record 313 of 598 | gurgan
# gurgan not found...skipping
# processing record 314 of 598 | viligili
# viligili not found...skipping
# processing record 315 of 598 | piacabucu
# processing record 316 of 598 | saint-joseph
# processing record 317 of 598 | saint george
# processing record 318 of 598 | saskylakh
# processing record 319 of 598 | aripuana
# processing record 320 of 598 | libertador general san martin
# processing record 321 of 598 | claresholm
# processing record 322 of 598 | samalaeulu
# samalaeulu not found...skipping
# processing record 323 of 598 | beringovskiy
# processing record 324 of 598 | knysna
# processing record 325 of 598 | wahlstedt
# processing record 326 of 598 | harper
# processing record 327 of 598 | makakilo city
# processing record 328 of 598 | te anau
# processing record 329 of 598 | cidreira
# processing record 330 of 598 | palabuhanratu
# palabuhanratu not found...skipping
# processing record 331 of 598 | avera
# processing record 332 of 598 | mampong
# processing record 333 of 598 | itaberai
# processing record 334 of 598 | rincon
# processing record 335 of 598 | hunza
# hunza not found...skipping
# processing record 336 of 598 | port hardy
# processing record 337 of 598 | mwinilunga
# processing record 338 of 598 | krasnyy kholm
# processing record 339 of 598 | khatanga
# processing record 340 of 598 | bengkulu
# processing record 341 of 598 | alyangula
# processing record 342 of 598 | cascavel
# processing record 343 of 598 | yanchukan
# yanchukan not found...skipping
# processing record 344 of 598 | laranjeiras
# processing record 345 of 598 | port hedland
# processing record 346 of 598 | boa vista
# processing record 347 of 598 | haines junction
# processing record 348 of 598 | barranca
# processing record 349 of 598 | foam lake
# processing record 350 of 598 | oriximina
# processing record 351 of 598 | nayagarh
# processing record 352 of 598 | swakopmund
# processing record 353 of 598 | noumea
# processing record 354 of 598 | tessalit
# processing record 355 of 598 | daru
# processing record 356 of 598 | bonavista
# processing record 357 of 598 | kalmunai
# processing record 358 of 598 | moose factory
# processing record 359 of 598 | lagoa
# processing record 360 of 598 | isla mujeres
# processing record 361 of 598 | zorritos
# processing record 362 of 598 | naifaru
# processing record 363 of 598 | capaci
# processing record 364 of 598 | saint anthony
# processing record 365 of 598 | atar
# processing record 366 of 598 | burns lake
# processing record 367 of 598 | malakal
# processing record 368 of 598 | chagda
# chagda not found...skipping
# processing record 369 of 598 | ilulissat
# processing record 370 of 598 | chernyshevskiy
# processing record 371 of 598 | dir
# processing record 372 of 598 | huarmey
# processing record 373 of 598 | lermontovka
# processing record 374 of 598 | whittlesea
# processing record 375 of 598 | staroye drozhzhanoye
# processing record 376 of 598 | cap-aux-meules
# processing record 377 of 598 | parubcan
# parubcan not found...skipping
# processing record 378 of 598 | lorengau
# processing record 379 of 598 | ukiah
# processing record 380 of 598 | nguiu
# nguiu not found...skipping
# processing record 381 of 598 | grand baie
# processing record 382 of 598 | curup
# processing record 383 of 598 | arrifes
# processing record 384 of 598 | sulangan
# processing record 385 of 598 | takoradi
# processing record 386 of 598 | san patricio
# processing record 387 of 598 | bur gabo
# bur gabo not found...skipping
# processing record 388 of 598 | kaitangata
# processing record 389 of 598 | pangody
# processing record 390 of 598 | fortuna
# processing record 391 of 598 | lata
# processing record 392 of 598 | bud
# processing record 393 of 598 | whitehorse
# processing record 394 of 598 | kirkwall
# processing record 395 of 598 | odienne
# processing record 396 of 598 | juneau
# processing record 397 of 598 | katobu
# processing record 398 of 598 | thunder bay
# processing record 399 of 598 | doctor pedro p. pena
# doctor pedro p. pena not found...skipping
# processing record 400 of 598 | kathu
# processing record 401 of 598 | nelson bay
# processing record 402 of 598 | valsamata
# processing record 403 of 598 | kununurra
# processing record 404 of 598 | sombreffe
# processing record 405 of 598 | ginir
# processing record 406 of 598 | filadelfia
# processing record 407 of 598 | vanavara
# processing record 408 of 598 | balakhta
# processing record 409 of 598 | inongo
# processing record 410 of 598 | saint-paul
# processing record 411 of 598 | soyo
# processing record 412 of 598 | varberg
# processing record 413 of 598 | tabou
# processing record 414 of 598 | matara
# processing record 415 of 598 | humaita
# processing record 416 of 598 | pitimbu
# processing record 417 of 598 | lasa
# processing record 418 of 598 | tidore
# tidore not found...skipping
# processing record 419 of 598 | iqaluit
# processing record 420 of 598 | hofn
# processing record 421 of 598 | shebunino
# processing record 422 of 598 | codrington
# processing record 423 of 598 | yarmouth
# processing record 424 of 598 | enkhuizen
# processing record 425 of 598 | yanam
# processing record 426 of 598 | springfield
# processing record 427 of 598 | marathon
# processing record 428 of 598 | cabuyaro
# processing record 429 of 598 | ridgecrest
# processing record 430 of 598 | lac-megantic
# processing record 431 of 598 | madang
# processing record 432 of 598 | anadyr
# processing record 433 of 598 | flinders
# processing record 434 of 598 | inyonga
# processing record 435 of 598 | havoysund
# processing record 436 of 598 | concepcion del oro
# processing record 437 of 598 | mecca
# processing record 438 of 598 | ucluelet
# processing record 439 of 598 | bandarbeyla
# processing record 440 of 598 | simao dias
# processing record 441 of 598 | marsh harbour
# processing record 442 of 598 | sola
# processing record 443 of 598 | okhotsk
# processing record 444 of 598 | pierre
# processing record 445 of 598 | raudeberg
# processing record 446 of 598 | barawe
# barawe not found...skipping
# processing record 447 of 598 | uglich
# processing record 448 of 598 | ingham
# processing record 449 of 598 | cap malheureux
# processing record 450 of 598 | zhigansk
# processing record 451 of 598 | grand gaube
# processing record 452 of 598 | esperance
# processing record 453 of 598 | hualmay
# processing record 454 of 598 | evensk
# processing record 455 of 598 | chatellerault
# processing record 456 of 598 | bomet
# processing record 457 of 598 | liverpool
# processing record 458 of 598 | kaberamaido
# processing record 459 of 598 | santiago
# processing record 460 of 598 | grand centre
# grand centre not found...skipping
# processing record 461 of 598 | pangnirtung
# processing record 462 of 598 | matamoros
# processing record 463 of 598 | ribeira grande
# processing record 464 of 598 | shenjiamen
# processing record 465 of 598 | balad
# processing record 466 of 598 | yelizovo
# processing record 467 of 598 | namatanai
# processing record 468 of 598 | miandrivazo
# processing record 469 of 598 | kosa
# processing record 470 of 598 | wa
# wa not found...skipping
# processing record 471 of 598 | tutoia
# processing record 472 of 598 | muros
# processing record 473 of 598 | beloha
# processing record 474 of 598 | talaya
# processing record 475 of 598 | kabinda
# processing record 476 of 598 | praia da vitoria
# processing record 477 of 598 | svetlyy
# processing record 478 of 598 | oranjemund
# processing record 479 of 598 | ambilobe
# processing record 480 of 598 | barreirinha
# processing record 481 of 598 | tubmanburg
# processing record 482 of 598 | opuwo
# processing record 483 of 598 | singapore
# processing record 484 of 598 | arlit
# processing record 485 of 598 | touros
# processing record 486 of 598 | abu kamal
# processing record 487 of 598 | buala
# processing record 488 of 598 | mount gambier
# processing record 489 of 598 | chimbarongo
# processing record 490 of 598 | bereda
# processing record 491 of 598 | fairbanks
# processing record 492 of 598 | jieshi
# processing record 493 of 598 | santa eulalia del rio
# santa eulalia del rio not found...skipping
# processing record 494 of 598 | maturin
# processing record 495 of 598 | port macquarie
# processing record 496 of 598 | henties bay
# processing record 497 of 598 | saint albans
# processing record 498 of 598 | nemuro
# processing record 499 of 598 | pangkalanbuun
# processing record 500 of 598 | contamana
# processing record 501 of 598 | hobyo
# processing record 502 of 598 | burica
# burica not found...skipping
# processing record 503 of 598 | benguela
# processing record 504 of 598 | digby
# processing record 505 of 598 | abalak
# processing record 506 of 598 | necochea
# processing record 507 of 598 | bolungarvik
# bolungarvik not found...skipping
# processing record 508 of 598 | gurupi
# processing record 509 of 598 | izhmorskiy
# processing record 510 of 598 | ueda
# processing record 511 of 598 | ejura
# processing record 512 of 598 | kempele
# processing record 513 of 598 | neuquen
# processing record 514 of 598 | pimenta bueno
# processing record 515 of 598 | wajima
# processing record 516 of 598 | nouadhibou
# processing record 517 of 598 | beypur
# beypur not found...skipping
# processing record 518 of 598 | waounde
# processing record 519 of 598 | virginia beach
# processing record 520 of 598 | tunduru
# tunduru not found...skipping
# processing record 521 of 598 | verkhoyansk
# processing record 522 of 598 | naze
# processing record 523 of 598 | tual
# processing record 524 of 598 | hakkari
# processing record 525 of 598 | tongliao
# processing record 526 of 598 | axim
# processing record 527 of 598 | sorvag
# sorvag not found...skipping
# processing record 528 of 598 | jupiter
# processing record 529 of 598 | mackay
# processing record 530 of 598 | floro
# processing record 531 of 598 | krionerion
# krionerion not found...skipping
# processing record 532 of 598 | shemonaikha
# processing record 533 of 598 | dekoa
# dekoa not found...skipping
# processing record 534 of 598 | oktyabrskiy
# processing record 535 of 598 | russell
# processing record 536 of 598 | bima
# processing record 537 of 598 | marzuq
# processing record 538 of 598 | marsabit
# processing record 539 of 598 | akyab
# processing record 540 of 598 | nova olinda do norte
# processing record 541 of 598 | narok
# processing record 542 of 598 | mpika
# processing record 543 of 598 | margate
# processing record 544 of 598 | ocampo
# processing record 545 of 598 | oranjestad
# processing record 546 of 598 | san cristobal
# processing record 547 of 598 | tahta
# processing record 548 of 598 | faya
# processing record 549 of 598 | vestmannaeyjar
# processing record 550 of 598 | hirara
# processing record 551 of 598 | kirakira
# processing record 552 of 598 | novyy urengoy
# processing record 553 of 598 | santiago de cao
# processing record 554 of 598 | abu samrah
# processing record 555 of 598 | mamlyutka
# processing record 556 of 598 | sao jose da coroa grande
# processing record 557 of 598 | port-gentil
# processing record 558 of 598 | padilla
# processing record 559 of 598 | chambery
# processing record 560 of 598 | gizo
# processing record 561 of 598 | kiruna
# processing record 562 of 598 | veraval
# processing record 563 of 598 | nkowakowa
# processing record 564 of 598 | zhuhai
# processing record 565 of 598 | kashi
# processing record 566 of 598 | bansi
# processing record 567 of 598 | brandfort
# processing record 568 of 598 | imbituba
# processing record 569 of 598 | zaysan
# processing record 570 of 598 | mergui
# mergui not found...skipping
# processing record 571 of 598 | valdivia
# processing record 572 of 598 | ponta delgada
# processing record 573 of 598 | birakan
# processing record 574 of 598 | ola
# processing record 575 of 598 | puerto escondido
# processing record 576 of 598 | tikapur
# processing record 577 of 598 | weligama
# processing record 578 of 598 | caucaia
# processing record 579 of 598 | guilin
# processing record 580 of 598 | breves
# processing record 581 of 598 | itacare
# processing record 582 of 598 | bureya
# processing record 583 of 598 | hvolsvollur
# processing record 584 of 598 | burgeo
# processing record 585 of 598 | houston
# processing record 586 of 598 | saint-pierre
# processing record 587 of 598 | corat
# processing record 588 of 598 | qaqortoq
# processing record 589 of 598 | le portel
# processing record 590 of 598 | jumla
# processing record 591 of 598 | maningrida
# processing record 592 of 598 | salamiyah
# processing record 593 of 598 | hambantota
# processing record 594 of 598 | samur
# processing record 595 of 598 | quelimane
# processing record 596 of 598 | afikpo
# processing record 597 of 598 | college

# %%
## Clean up data from json and store in new variable - clean_weather_df
clean_weather_df = city_weather_df.replace(r'^\s*$', np.nan, regex=True)
clean_weather_df = clean_weather_df.dropna(axis=0,how='any')
clean_weather_df.head()
# Out:
#              City      Lat      Long  Max Temp  Humidity  Cloudiness  \
# 0          dingle  10.9995  122.6711     81.64      83.0        91.0
# 1       busselton -33.6500  115.3333     70.00      49.0         0.0
# 2  guerrero negro  27.9769 -114.0611     55.56      64.0         0.0
# 3           bluff -46.6000  168.3333     64.99      71.0         0.0
# 4      bredasdorp -34.5322   20.0403     51.80      93.0        45.0
#
#    Wind Speed Country          Date
# 0        6.33      PH  1.615609e+09
# 1        3.00      AU  1.615609e+09
# 2       12.77      MX  1.615609e+09
# 3        5.99      NZ  1.615609e+09
# 4        1.14      ZA  1.615609e+09

# %%
## Export data to csv file
clean_weather_df.to_csv('../Output/weather_data.csv',index=False)

# %%
## display summary statistics for clean_weather_df
clean_weather_df.describe(include=[np.number])
# Out:
#               Lat        Long    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  546.000000  546.000000  546.000000  546.000000  546.000000  546.000000
# mean    19.527006   17.588099   54.782637   71.857143   52.780220    8.830440
# std     32.830223   88.719582   27.099415   20.305504   39.042382    6.420643
# min    -54.800000 -175.200000  -20.200000   11.000000    0.000000    0.540000
# 25%     -7.453425  -58.715150   37.412500   62.000000    6.250000    3.985000
# 50%     22.281200   20.785700   60.800000   75.000000   63.000000    6.890000
# 75%     48.204125   95.179200   77.000000   88.000000   90.000000   12.395000
# max     78.218600  179.316700   96.840000  100.000000  100.000000   37.870000
#
#                Date
# count  5.460000e+02
# mean   1.615609e+09
# std    8.478202e+01
# min    1.615609e+09
# 25%    1.615609e+09
# 50%    1.615609e+09
# 75%    1.615609e+09
# max    1.615609e+09

# %%
## seperate humid cities from ideal cities and display summary statistics for humid cities
humid_city_df = clean_weather_df.loc[clean_weather_df['Humidity']>=100]
ideal_city_df = clean_weather_df.loc[clean_weather_df['Humidity']<100]
humid_city_df.describe(include=[np.number])
# Out:
#              Lat        Long   Max Temp  Humidity  Cloudiness  Wind Speed  \
# count   9.000000    9.000000   9.000000       9.0    9.000000    9.000000
# mean   14.417222  -35.800500  54.446667     100.0   53.777778    6.915556
# std    33.851398   61.921604  16.008141       0.0   37.234990    7.215161
# min   -38.650000 -130.320100  35.010000     100.0    0.000000    1.990000
# 25%    -5.134700  -72.233300  41.000000     100.0   18.000000    3.440000
# 50%    10.160300  -49.326700  51.010000     100.0   75.000000    4.610000
# 75%    36.297000   22.301000  68.000000     100.0   75.000000    6.910000
# max    60.306700   59.606200  75.200000     100.0   90.000000   25.320000
#
#                Date
# count  9.000000e+00
# mean   1.615609e+09
# std    3.608478e+01
# min    1.615609e+09
# 25%    1.615609e+09
# 50%    1.615609e+09
# 75%    1.615609e+09
# max    1.615609e+09

# %%
## Temperature (F) vs. Latitude
temp = ideal_city_df['Max Temp']
lat = ideal_city_df['Lat']

## Plot data
plt.figure(figsize=(15,9))
plt.scatter(lat,temp,s=80,edgecolors='black')
plt.title('Max Temperature vs. Latitude',fontsize = 24)
plt.ylabel('Temperature (Fahrenheit)',fontsize = 20)
plt.xlabel('Latitude',fontsize=20)
plt.grid(which='major')


plt.show()

# %%
## Humidity (%) vs. Latitude

hum = ideal_city_df['Humidity']
lat = ideal_city_df['Lat']

## plot data
plt.figure(figsize=(15,9))
plt.scatter(lat, hum,s=80,edgecolors='black')
plt.title('Humidity vs. Latitude',fontsize = 24)
plt.ylabel('Humidity',fontsize = 20)
plt.xlabel('Latitude',fontsize=20)
plt.grid(which='major')

plt.show()

# %%
## Cloudiness (%) vs. Latitude

cloud = ideal_city_df['Cloudiness']
lat = ideal_city_df['Lat']

## plot data
plt.figure(figsize=(15,9))
plt.scatter(lat,cloud,s=80,edgecolors='black')
plt.title('Cloudiness vs. Latitude',fontsize = 24)
plt.ylabel('Cloudiness',fontsize = 20)
plt.xlabel('Latitude',fontsize=20)
plt.grid(which='major')

plt.show()

# %%
## Wind Speed (mph) vs. Latitude

wind = ideal_city_df['Wind Speed']
lat = ideal_city_df['Lat']

## plot data
plt.figure(figsize=(15,9))
plt.scatter(lat,wind,s=80,edgecolors='black')
plt.title('Wind Speed vs. Latitude',fontsize = 24)
plt.ylabel('Wind Speed (mph)',fontsize = 20)
plt.xlabel('Latitude',fontsize=20)
plt.grid(which='major')

plt.show()

# %%
## Seperate cities into new data frames for nothern and southern hemispheres
northern_hem = clean_weather_df.loc[clean_weather_df['Lat']>=0]
southern_hem = clean_weather_df.loc[clean_weather_df['Lat']<0]

# %%
## Hemisphere Temperature (F) vs. Latitude

fig1, (ax1,ax2) = plt.subplots(1,2,figsize=(20,5))


## Northern Hemisphere - Temperature (F) vs. Latitude
## variables
north_temp = northern_hem['Max Temp']
north_lat = northern_hem['Lat']

## Linear Regression
(slope, intercept, nrvalue, pvalue, stderr) = st.linregress(north_lat, north_temp)
temp1_regress_values = (slope * north_lat) + intercept
ntemp_line_eq = f'y = {round(slope,2)}x + {round(intercept,2)}'

## Plot Data on left subplot
ax1.scatter(north_lat,north_temp,s=80,edgecolors='black')
ax1.plot(north_lat,temp1_regress_values,color='red')
ax1.annotate(ntemp_line_eq,(50,80),fontsize=18,color="red")
ax1.set_title('Max Temperature Northern Hemisphere',fontsize = 24)
ax1.set_ylabel('Temperature (Fahrenheit)',fontsize = 20)
ax1.set_xlabel(f'Latitude \n\nr-value: {nrvalue}',fontsize=20)
ax1.grid(which='major')


## Southern Hemisphere - Temperature (F) vs. Latitude
## variables
south_temp = southern_hem['Max Temp']
south_lat = southern_hem['Lat']

## Linear Regression
(slope, intercept, srvalue, pvalue, stderr) = st.linregress(south_lat, south_temp)
temp2_regress_values = (slope * south_lat) + intercept
stemp_line_eq = f'y = {round(slope,2)}x + {round(intercept,2)}'

## Plot Data on right subplot
ax2.scatter(south_lat,south_temp,s=80,edgecolors='black')
ax2.plot(south_lat,temp2_regress_values,color='red')
ax2.annotate(stemp_line_eq,(-50,55),fontsize=18,color="red")
ax2.set_title('Max Temperature Southern Hemisphere',fontsize = 24)
ax2.set_xlabel(f'Latitude \n\nr-value: {srvalue}',fontsize=20)
ax2.grid(which='major')

## Print correlation coefficient


plt.show()

# %%
## Northern Hemisphere - Humidity (%) vs. Latitude

## Define Figure 2
fig2, (ax1,ax2) = plt.subplots(1,2,figsize=(20,7))

## variables
north_hum = northern_hem['Humidity']
north_lat = northern_hem['Lat']

## Linear Regression
(slope, intercept, nrvalue, pvalue, stderr) = st.linregress(north_lat, north_hum)
hum1_regress_values = (slope * north_lat) + intercept
nhum_line_eq = f'y = {round(slope,2)}x + {round(intercept,2)}'

## Plot Data on left subplot
ax1.scatter(north_lat,north_hum,s=80,edgecolors='black')
ax1.plot(north_lat,hum1_regress_values,color='red')
ax1.annotate(nhum_line_eq,(0,42),fontsize=18,color="red")
ax1.set_title('Humidity - Northern Hemisphere',fontsize = 24)
ax1.set_ylabel('Humidity (%)',fontsize = 20)
ax1.set_xlabel(f'Latitude \n\nr-value: {nrvalue}',fontsize=20)
ax1.grid(which='major')

## Southern Hemisphere - Humidity (%) vs. Latitude
## variables
south_hum = southern_hem['Humidity']
south_lat = southern_hem['Lat']

## Linear Regression
(slope, intercept, srvalue, pvalue, stderr) = st.linregress(south_lat, south_hum)
hum2_regress_values = (slope * south_lat) + intercept
shum_line_eq = f'y = {round(slope,2)}x + {round(intercept,2)}'

## Plot Data on right subplot
ax2.scatter(south_lat,south_hum,s=80,edgecolors='black')
ax2.plot(south_lat,hum2_regress_values,color='red')
ax2.annotate(shum_line_eq,(-30,55),fontsize=18,color="red")
ax2.set_title('Humidity - Southern Hemisphere',fontsize = 24)
ax2.set_xlabel(f'Latitude \n\nr-value: {srvalue}',fontsize=20)
ax2.grid(which='major')

plt.show()

# %%
## Northern Hemisphere - Cloudiness (%) vs. Latitude

## Define Figure for subplots
fig3, (ax1,ax2) = plt.subplots(1,2,figsize=(20,5))

## variables
north_cloud = northern_hem['Cloudiness']
north_lat = northern_hem['Lat']

## Linear Regression
(slope, intercept, nrvalue, pvalue, stderr) = st.linregress(north_lat, north_cloud)
cloud1_regress_values = (slope * north_lat) + intercept
ncloud_line_eq = f'y = {round(slope,2)}x + {round(intercept,2)}'

## Plot Data on left subplot
ax1.scatter(north_lat,north_cloud,s=80,edgecolors='black')
ax1.plot(north_lat,cloud1_regress_values,color='red')
ax1.annotate(ncloud_line_eq,(15,55),fontsize=18,color="red")
ax1.set_title('Cloudiness - Northern Hemisphere',fontsize = 24)
ax1.set_ylabel('Cloudiness (%)',fontsize = 20)
ax1.set_xlabel(f'Latitude \n\nr-value: {nrvalue}',fontsize=20)
ax1.grid(which='major')

## Southern Hemisphere - Cloudiness (%) vs. Latitude
## variables
south_cloud = southern_hem['Cloudiness']
south_lat = southern_hem['Lat']

## Linear Regression
(slope, intercept, srvalue, pvalue, stderr) = st.linregress(south_lat, south_cloud)
cloud2_regress_values = (slope * south_lat) + intercept
scloud_line_eq = f'y = {round(slope,2)}x + {round(intercept,2)}'

## Plot Data on right subplot
ax2.scatter(south_lat,south_cloud,s=80,edgecolors='black')
ax2.plot(south_lat,cloud2_regress_values,color='red')
ax2.annotate(scloud_line_eq,(-55,52),fontsize=18,color="red")
ax2.set_title('Cloudiness - Southern Hemisphere',fontsize = 24)
ax2.set_xlabel(f'Latitude \n\nr-value: {srvalue}',fontsize=20)
ax2.grid(which='major')

plt.show()

# %%
## Northern Hemisphere - Wind Speed (mph) vs. Latitude

## Define Figure 4 for subplots
fig4, (ax1,ax2) = plt.subplots(1,2,figsize=(20,5))

## variables
north_wind = northern_hem['Wind Speed']
north_lat = northern_hem['Lat']

## Linear Regression
(slope, intercept, nrvalue, pvalue, stderr) = st.linregress(north_lat, north_wind)
wind1_regress_values = (slope * north_lat) + intercept
nwind_line_eq = f'y = {round(slope,2)}x + {round(intercept,2)}'

## Plot Data on left subplot
ax1.scatter(north_lat,north_wind,s=80,edgecolors='black')
ax1.plot(north_lat,wind1_regress_values,color='red')
ax1.annotate(nwind_line_eq,(15,30),fontsize=18,color="red")
ax1.set_title('Wind Speed - Northern Hemisphere',fontsize = 24)
ax1.set_ylabel('Wind Speed (mph)',fontsize = 20)
ax1.set_xlabel(f'Latitude \n\nr-value: {nrvalue}',fontsize=20)
ax1.grid(which='major')

## Southern Hemisphere - Wind Speed (mph) vs. Latitude
## variables
south_wind = southern_hem['Wind Speed']
south_lat = southern_hem['Lat']

## Linear Regression
(slope, intercept, srvalue, pvalue, stderr) = st.linregress(south_lat, south_wind)
wind2_regress_values = (slope * south_lat) + intercept
swind_line_eq = f'y = {round(slope,2)}x + {round(intercept,2)}'

## Plot Data on right subplot
ax2.scatter(south_lat,south_wind,s=80,edgecolors='black')
ax2.plot(south_lat,wind2_regress_values,color='red')
ax2.annotate(swind_line_eq,(-30,25),fontsize=18,color="red")
ax2.set_title('Wind Speed - Southern Hemisphere',fontsize = 24)
ax2.set_xlabel(f'Latitude \n\nr-value: {srvalue}',fontsize=20)
ax2.grid(which='major')

plt.show()
